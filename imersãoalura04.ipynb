# %% [markdown]
# 💡**Criei uma cópia da Aula 02 para aproveitar os códigos anteriores. Abaixo está sendo informado onde começa a Aula 03.**

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %% [markdown]
# Incluindo códigos da aula 01 para exercitar e também para aproveitar o que já foi trabalhado no arquivo CSV.

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.columns =[
    'ano',
    'senioridade',
    'contrato',
    'cargo',
    'salario',
    'moeda',
    'salario_usd',
    'residencia',
    'remoto',
    'empresa',
    'porte_empresa'
]

print(df.columns)
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda',
#        'salario_usd', 'residencia', 'remoto', 'empresa', 'porte_empresa'],
#       dtype='object')

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df['senioridade'] = df['senioridade'].replace({
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
})

print(df['senioridade'].value_counts())
# Out:
# senioridade
# Sênior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
df['porte_empresa'] = df['porte_empresa'].replace({
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'

})

print(df['porte_empresa'].value_counts())
# Out:
# porte_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
df['contrato'] = df['contrato'].replace({
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Meio Período',
    'FL': 'Freelancer'
})

print(df['contrato'].value_counts())
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Freelancer            16
# Name: count, dtype: int64

# %%
df['remoto'] = df['remoto'].replace({
    0: 'Presencial',
    100: 'Remoto',
    50: 'Híbrido'
})

print(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %% [markdown]
# ▶ **Aqui abaixo começa as práticas da Aula 02:**

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda  salario_usd  \
# 0       False        False     False  False    False  False        False
# 1       False        False     False  False    False  False        False
# 2       False        False     False  False    False  False        False
# 3       False        False     False  False    False  False        False
# 4       False        False     False  False    False  False        False
# ...       ...          ...       ...    ...      ...    ...          ...
# 133344  False        False     False  False    False  False        False
# 133345  False        False     False  False    False  False        False
# 133346  False        False     False  False    False  False        False
# 133347  False        False     False  False    False  False        False
# 133348  False        False     False  False    False  False        False
#
#         residencia  remoto  empresa  porte_empresa
# ...

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %%
df.isnull().sum()
# Out:
# ano              10
# senioridade       0
# contrato          0
# cargo             0
# salario           0
# moeda             0
# salario_usd       0
# residencia        0
# remoto            0
# empresa           0
# porte_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %% [markdown]
# Abaixo estamos solicitando tudo que é null e exibindo essa dimensão (usando o axis)

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade        contrato                      cargo  salario  \
# 5588    NaN      Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN      Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda  salario_usd residencia      remoto empresa porte_empresa
# ...

# %% [markdown]
# Criação de DataFrame abaixo

# %%
#para colocar valores nulos
import numpy as np

#Criação de DataFrame de teste para exemplo
df_salarios = pd.DataFrame({
    'nome':  ['Ana','Bruno', 'Carlos', 'Daniele', 'Val'],
    'salario': [4000, np.nan, 5000, np.nan, 100000 ]
})

'''criando nova coluna 'salarios_media' que será preenchida a apartir do cálculo da média com base nos salários e assim preenche o que tá nulo na nova coluna'''
df_salarios['salarios_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2)) #calcula a media e arredonda
df_salarios['salarios_media'] = df_salarios['salario'].fillna(df_salarios['salario'].median()) #calcula a mediana
df_salarios
# Out:
#       nome   salario  salarios_media
# 0      Ana    4000.0          4000.0
# 1    Bruno       NaN          5000.0
# 2   Carlos    5000.0          5000.0
# 3  Daniele       NaN          5000.0
# 4      Val  100000.0        100000.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia': ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'],
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})

#ffill preenche com valor anterior (forward fill)
df_temperaturas['preenchido_ffill'] = df_temperaturas['Temperatura'].ffill()
df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_ffill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              30.0
# 2   Quarta          NaN              30.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia': ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'],
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})

#ffill preenche com o próximo valor (back)
df_temperaturas['Preenchido_bfill'] = df_temperaturas['Temperatura'].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  Preenchido_bfill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              28.0
# 2   Quarta          NaN              28.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
df_cidades = pd.DataFrame ({
    'Nome':  ['Ana','Bruno', 'Carlos', 'Daniele', 'Val'],
    'Cidade': ['São Paulo', np.nan, 'Curitiba', np.nan, 'Belém']

})

#Prenchimento com texto 'Não informado' onde era nulo
df_cidades['Cidade_Preenchida'] = df_cidades['Cidade'].fillna('Não informado')
df_cidades
# Out:
#       Nome     Cidade Cidade_Preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %% [markdown]
# Retomando o DataFrame da Aula 01 (usando método para remover campos nulos)

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano              0
# senioridade      0
# contrato         0
# cargo            0
# salario          0
# moeda            0
# salario_usd      0
# residencia       0
# remoto           0
# empresa          0
# porte_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ano            133339 non-null  float64
#  1   senioridade    133339 non-null  object
#  2   contrato       133339 non-null  object
#  3   cargo          133339 non-null  object
#  4   salario        133339 non-null  int64
#  5   moeda          133339 non-null  object
#  6   salario_usd    133339 non-null  int64
#  7   residencia     133339 non-null  object
#  8   remoto         133339 non-null  object
#  9   empresa        133339 non-null  object
#  10  porte_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
#atribuição de outro tipo na coluna ano
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %% [markdown]
# ✅ **Códigos da Aula 03 começam logo abaixo:**

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar',title='Distribuição de Senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de Senioridade'}, xlabel='senioridade'>

# %% [markdown]
# Biblioteca para personalizar gráficos.

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='senioridade', y='salario_usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='salario_usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='salario_usd')
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual (USD)')
plt.show()

# %%
#agrupando e organizando do maior valor para o menor
df_limpo.groupby('senioridade')['salario_usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Sênior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: salario_usd, dtype: float64

# %%
#criando variável para armazenar os valores em uma lista com os nomes da tabela senioridade
ordem = df_limpo.groupby('senioridade')['salario_usd'].mean().sort_values(ascending=True).index
ordem
# Out:
# Index(['Júnior', 'Pleno', 'Sênior', 'Executivo'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='salario_usd', order=ordem)
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual (USD)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['salario_usd'], bins=50, kde=True)
plt.title('Distribuição dos salários anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
  plt.figure(figsize=(8,5))
  sns.boxplot(x=df_limpo['salario_usd'])
  plt.title('Bloxplot salário')
  plt.xlabel('Salário em USD')
  plt.show()

# %%
ordem_senioridade= ['Júnior', 'Pleno', 'Sênior', 'Executivo']


plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='salario_usd', data=df_limpo, order=ordem_senioridade)
plt.title('Distribuição salarial por senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_senioridade= ['Júnior', 'Pleno', 'Sênior', 'Executivo']


plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='salario_usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title('Distribuição salarial por senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
import plotly.express as px

# %%
df_senioridade_salario = df_limpo.groupby('senioridade')['salario_usd'].mean().reset_index()

ordem_senioridade = ['Júnior', 'Pleno', 'Sênior', 'Executivo']

fig = px.bar(df_senioridade_salario,
             x='senioridade',
             y='salario_usd',
             title='Média Salarial por Senioridade',
             labels={'senioridade': 'Senioridade', 'salario_usd': 'Salário Médio Anual (USD)'},
             category_orders={'senioridade': ordem_senioridade})

fig.update_layout(xaxis_title='Senioridade', yaxis_title='Salário Médio Anual (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names= 'tipo_trabalho',
             values='quantidade',
             title= 'Proporção dos tipos de Trabalho'
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names= 'tipo_trabalho',
             values='quantidade',
             title= 'Proporção dos Tipos de Trabalho',
             hole=0.5
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names= 'tipo_trabalho',
             values='quantidade',
             title= 'Proporção dos tipos de Trabalho'
             )
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 🎯**DESAFIO**
#
# Crie um gráfico que mostre o salário médio de um cientista de dados (Data Scientist) por país.
#
# Minha resolução abaixo:

# %%
'''df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %%
'''df_data_scientist = df_limpo[df_limpo['cargo'] == 'Data Scientist']

# %%
'''len(df_data_scientist)
# Out:
# 17311

# %%
'''df_salario_por_pais = df_data_scientist.groupby('residencia')['salario_usd'].mean()

# %%
'''df_salario_por_pais = df_salario_por_pais.reset_index()

fig = px.bar(df_salario_por_pais,
             x='residencia',
             y='salario_usd',
             title='Média Salarial do cargo Data Scientist por país',
            )

fig.update_layout(xaxis_title='País', yaxis_title='Média Salarial do cargo Data Scientist por país')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **AULA 04 ABAIXO:**

# %% [markdown]
# 🎯**DESAFIO**
#
# Crie um gráfico que mostre o salário médio de um cientista de dados (Data Scientist) por país.
#
# **RESOLUÇÃO NA AULA 04**

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa
# 0       214000         US      Remoto      US         Médio
# 1       136000         US      Remoto      US         Médio
# 2       158800         AU  Presencial      AU         Médio
# 3       139200         AU  Presencial      AU         Médio
# 4        90000         US  Presencial      US         Médio

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 53.1 MB/s eta 0:00:00
# ...

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
  try:
     return pycountry.countries.get(alpha_2=code).alpha_3
  except:
    return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['salario_usd'].mean().reset_index()

# Gerar mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='salario_usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio do Cientista de Dados por país',
                    labels={'salario_usd': 'Salário médio(USD)', 'residencia_iso3': 'País'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_usd residencia      remoto empresa porte_empresa residencia_iso3
# 0       214000         US      Remoto      US         Médio             USA
# 1       136000         US      Remoto      US         Médio             USA
# 2       158800         AU  Presencial      AU         Médio             AUS
# 3       139200         AU  Presencial      AU         Médio             AUS
# 4        90000         US  Presencial      US         Médio             USA

# %% [markdown]
# # **COMO SALVAR A BASE PARA UTILIZAR APÓS TRATAMENTO DOS DADOS**

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)
